# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
# Calling 2 diffrent datasets
dataset = pd.read_csv('Helsinki_rent_data_july_2020.csv')
df = pd.read_csv('Helsinki_rent_data_july_2020.csv')

# %%
dataset.head(5)
# Out:
#       ID   HouseType  Size  MonthlyRentals      City  Sauna  Balcony  \
# 0   4561  kerrostalo  17.8             295  Helsinki      0        0
# 1   6711  kerrostalo  17.8             295  Helsinki      0        0
# 2  16643  kerrostalo  17.8             295  Helsinki      0        0
# 3  13998  kerrostalo  25.0             350  Helsinki      0        0
# 4   7619  kerrostalo  25.0             370  Helsinki      0        0
#
#                                 Address   Latitude  Longitude  Number_Of_Rooms
# 0        Ida Aalbergin, 00400, Helsinki  60.230411  24.900260                1
# 1        Ida Aalbergin, 00400, Helsinki  60.230411  24.900260                1
# 2        Ida Aalbergin, 00400, Helsinki  60.230411  24.900260                1
# 3  Valhallankatu 5.A.1, 00250, Helsinki  60.184918  24.912827                0
# 4      Valhallankatu 5, 00250, Helsinki  60.184028  24.913289                0

# %%
# Deleting what is not needed
del dataset['City'], dataset['Address'], dataset['MonthlyRentals'], dataset['Latitude'], dataset['Longitude'], dataset['Number_Of_Rooms']

# %%
# Replacing the NAN value with the mean value for both datasets
dataset = dataset.fillna(dataset.mean())
df = df.fillna(df.mean())

# %%
# Assigning variables to the x axis and y axis
X = dataset.iloc[:, 2:].values
y = df.iloc[:, 3].values

# %%
print(X)
# Out:
# [[17.8         0.          0.        ]
#  [17.8         0.          0.        ]
#  [17.8         0.          0.        ]
#  ...
#  [52.13792749  1.          0.        ]
#  [80.          0.          0.        ]
#  [39.          1.          1.        ]]

# %%
# This code will let you split the data set into trained and tested, test size 20% and train size is 80%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
# Training the Simple Linear Regression model on the Training set
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
y_pred = lin_reg.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[2307.06 1550.  ]
#  [ 852.85  799.  ]
#  [1491.57 1172.  ]
#  [1278.97  945.  ]
#  [1193.07 1150.  ]
#  [ 900.2  1225.  ]
#  [2320.59 3561.  ]
#  [1522.47 1529.  ]
#  [1103.11  890.  ]
#  [1109.88 1198.  ]
#  [1177.51  800.  ]
#  [1221.01  975.  ]
#  [1008.42 1100.  ]
#  [1035.47  990.  ]
#  [1170.75  980.  ]
#  [1532.27 1096.  ]
#  [1204.57 1349.  ]
#  [1488.65  895.  ]
#  [ 869.09  720.  ]
#  [1224.86 1199.  ]
#  [1082.82  998.  ]
#  [1454.83 1850.  ]
#  [1714.89 2847.  ]
#  [1373.66  999.  ]
#  [1620.2  1350.  ]
#  [1414.25  862.  ]
#  [1123.4  1075.  ]
#  [1251.92 1450.  ]
#  [1197.81 1059.  ]
#  [2468.58 3298.  ]
#  [1282.01  650.  ]
#  [1944.74 2200.  ]
#  [1096.35  952.  ]
#  [ 940.78  790.  ]
#  [ 893.44 1234.  ]
#  [ 839.33  869.  ]
#  [ 859.62  999.  ]
#  [1319.55 1180.  ]
#  [ 852.85  839.  ]
#  [1306.03  959.  ]
#  [1786.25 1200.  ]
#  [1312.79 1350.  ]
#  [1572.85 1222.  ]
#  [1103.11  937.  ]
#  [1278.97  949.  ]
#  [1617.16 1211.  ]
#  [1535.99 1289.  ]
#  [1191.04  971.  ]
#  [2009.46 3900.  ]
#  [1488.65 1499.  ]
#  [1055.77  819.  ]
#  [ 974.6   945.  ]
#  [1866.61 3059.  ]
#  [1065.45  969.  ]
#  [1241.42 1240.  ]
#  [1109.88  861.  ]
#  [1197.81  850.  ]
#  [1660.66 1600.  ]
#  [1353.37 1792.  ]
#  [1941.82 2750.  ]
#  [1226.73 1039.  ]
#  [1549.52 2200.  ]
#  [1238.39 1099.  ]
#  [1643.4  1350.  ]
#  [1353.37 1225.  ]
#  [1288.77 1043.  ]
#  [1478.04  979.  ]
#  [1285.73 1075.  ]
#  [1238.39 1098.  ]
#  [ 879.91  845.  ]
#  [1251.92  923.  ]
#  [ 825.8   690.  ]
#  [1021.95 1040.  ]
#  [1829.75 1649.  ]
#  [1303.32 1420.  ]
#  [1170.75  838.  ]
#  [1322.59 1008.  ]
#  [1214.37 2663.  ]
#  [1278.97  939.  ]
#  [1525.38 1575.  ]
#  [1333.08 2483.  ]
#  [1940.47 2600.  ]
#  [2116.87 2500.  ]
#  [1265.44 1195.  ]
#  [1525.5   929.  ]
#  [ 873.14 1457.  ]
#  [1437.57 1020.  ]
#  [1222.88  850.  ]
#  [1109.88 1220.  ]
#  [1406.13 1129.  ]
#  [ 886.67 1800.  ]
#  [1745.67 1085.  ]
#  [ 940.78  720.  ]
#  [ 852.85  789.  ]
#  [1062.53  920.  ]
#  [1336.12  947.  ]
#  [1136.93 1490.  ]
#  [1082.01 1070.  ]
#  [1227.9  1290.  ]
#  [1018.22  790.  ]
#  [1103.11 1099.  ]
#  [1226.73  973.  ]
#  [1735.06 2550.  ]
#  [ 852.85  779.  ]
#  [1130.17  825.  ]
#  [1153.5   750.  ]
#  [1163.99  964.  ]
#  [ 900.2   810.  ]
#  [1254.95  890.  ]
#  [1224.86 1187.  ]
#  [ 913.73 1031.  ]
#  [1089.59  840.  ]
#  [1529.23 1580.  ]
#  [1103.11 1099.  ]
#  [1126.32 1180.  ]
#  [1735.06 1469.  ]
#  [1055.77  839.  ]
#  [1245.15  990.  ]
#  [ 967.84  917.  ]
#  [1191.04  960.  ]
#  [1008.42 1055.  ]
#  [1423.93 1337.  ]
#  [1130.17 1198.  ]
#  [ 913.73  950.  ]
#  [1829.75 2150.  ]
#  [1613.31 1710.  ]
#  [1549.52 1199.  ]
#  [1586.26 1399.  ]
#  [1437.45 1372.  ]
#  [1076.06  921.  ]
#  [ 839.33  699.  ]
#  [1312.79  959.  ]
#  [1076.06  999.  ]
#  [1150.46  955.  ]
#  [1333.08 1199.  ]
#  [1292.5   879.  ]
#  [ 879.91  930.  ]
#  [1226.73 1018.  ]
#  [1297.91  999.  ]
#  [1136.93 1185.  ]
#  [ 710.81  522.  ]
#  [ 852.85  839.  ]
#  [1055.77  627.  ]
#  [1326.32  979.  ]
#  [ 791.98 1457.  ]
#  [1667.42 1850.  ]
#  [1610.4  1520.  ]
#  [ 988.13  686.  ]
#  [1603.63 1600.  ]
#  [1671.27 3100.  ]
#  [1234.54  979.  ]
#  [1535.99 1239.  ]
#  [1380.43 1030.  ]
#  [1698.32 2315.  ]
#  [1227.9   850.  ]
#  [1610.4  1450.  ]
#  [1545.68 1490.  ]
#  [ 940.78  786.  ]
#  [1163.99  909.  ]
#  [1457.87 1056.  ]
#  [1299.26 1159.  ]
#  [ 778.45 1329.  ]
#  [1423.93 1585.  ]
#  [1820.07 1365.  ]
#  [2184.51 2599.  ]
#  [1136.93  945.  ]
#  [1238.39 1060.  ]
#  [1484.92 1102.  ]
#  [1163.99 1100.  ]
#  [1793.02 2800.  ]
#  [1062.53  990.  ]
#  [ 927.25 1480.  ]
#  [ 988.13  599.  ]
#  [1231.62 1061.  ]
#  [ 981.36  800.  ]
#  [1319.55  979.  ]
#  [1170.75 1131.  ]
#  [1049.    775.  ]
#  [1011.34 1139.  ]
#  [1268.48 2565.  ]
#  [ 656.7   522.  ]
#  [1278.97 1290.  ]
#  [1109.88 1249.  ]
#  [1184.28 1200.  ]
#  [ 852.85  839.  ]
#  [1103.11 1099.  ]
#  [1062.53 1195.  ]
#  [ 954.31 1131.  ]
#  [1566.09 2339.  ]
#  [ 886.67  690.  ]
#  [ 852.85  815.  ]
#  [1319.55  937.  ]
#  [1522.47 1250.  ]
#  [1272.21  975.  ]
#  [ 764.92  585.  ]
#  [1224.86 1179.  ]
#  [1508.94 1198.  ]
#  [ 920.49  979.  ]
#  [ 988.13 1030.  ]
#  [1522.47 2700.  ]
#  [1028.71  859.  ]
#  [1245.15 1040.  ]
#  [1095.54  915.  ]
#  [1339.04 1100.  ]
#  [1566.09  874.  ]
#  [1650.17 1372.  ]
#  [1049.    890.  ]
#  [1103.11  919.  ]
#  [1076.06  995.  ]
#  [1103.11 1069.  ]
#  [1306.03  935.  ]
#  [ 727.38  450.  ]
#  [1765.96 1028.  ]
#  [1153.5   920.  ]
#  [1099.27  980.  ]
#  [1563.05 1590.  ]
#  [1028.44  925.  ]
#  [ 900.2   970.  ]
#  [1326.32 1065.  ]
#  [1238.39  949.  ]
#  [1080.12 1150.  ]
#  [1226.73 1200.  ]
#  [ 893.44  749.  ]
#  [1417.28  795.  ]
#  [1197.81  890.  ]
#  [ 997.81  830.  ]
#  [1525.5   867.  ]
#  [1042.24  890.  ]
#  [ 903.24 1675.  ]
#  [1373.66 1384.  ]
#  [ 879.91  790.  ]
#  [ 751.4   650.  ]
#  [1008.42 1060.  ]
#  [1522.47 1453.  ]
#  [1173.79 1457.  ]
#  [ 988.13  980.  ]
#  [1306.03 1190.  ]
#  [1226.73  880.  ]
#  [1211.33 1450.  ]
#  [1813.31 2090.  ]
#  [1226.73 1178.  ]
#  [1596.87 1620.  ]
#  [ 984.4  1514.  ]
#  [1234.66 1100.  ]
#  [1052.04 2260.  ]
#  [1204.57 1329.  ]
#  [1076.06 1175.  ]
#  [1468.36 1567.  ]
#  [1299.26  859.  ]
#  [1211.33 1100.  ]
#  [1633.6  1599.  ]
#  [1393.95 1530.  ]
#  [1143.7   910.  ]
#  [1312.79  989.  ]
#  [ 859.62 1680.  ]
#  [1123.4   970.  ]
#  [1116.64  899.  ]
#  [1062.53 1900.  ]
#  [ 927.25  850.  ]
#  [ 981.36 2030.  ]
#  [1393.95 1450.  ]
#  [ 670.23  585.  ]
#  [ 923.53  820.  ]
#  [1241.42  945.  ]
#  [1028.71  930.  ]
#  [1130.17 1190.  ]
#  [ 913.73  729.  ]
#  [1150.46 1130.  ]
#  [1076.06 2414.  ]
#  [1123.4   990.  ]
#  [ 967.84  830.  ]
#  [1488.65 1499.  ]
#  [1241.31 1550.  ]
#  [1356.29 2381.  ]
#  [1173.67 1129.  ]
#  [1590.1  1600.  ]
#  [ 852.85  839.  ]
#  [1163.99 1200.  ]
#  [ 981.36 1836.  ]
#  [ 751.4   970.  ]
#  [1346.61 1340.  ]
#  [1931.21 2500.  ]
#  [1055.77 1303.  ]
#  [1088.23  998.  ]
#  [1146.73 1950.  ]
#  [ 852.85  839.  ]
#  [1572.73 1304.  ]
#  [1066.59 1050.  ]
#  [1028.71  940.  ]
#  [1207.61  890.  ]
#  [1035.47  929.  ]
#  [1082.82  931.  ]
#  [ 957.35  610.  ]
#  [1187.31 1390.  ]
#  [1264.09  919.  ]
#  [1163.99 1090.  ]
#  [1488.65 1549.  ]
#  [1191.04  915.  ]
#  [ 859.62 1209.  ]
#  [1103.11  999.  ]
#  [ 981.36  875.  ]
#  [1484.92 1350.  ]
#  [1042.24  990.  ]
#  [1529.23 1050.  ]
#  [1221.13  850.  ]
#  [2222.05 2735.  ]
#  [1356.29 1750.  ]
#  [1001.66 1085.  ]
#  [1238.39  949.  ]
#  [2093.66 1500.  ]
#  [ 947.55  995.  ]
#  [1177.51  890.  ]
#  [1319.55 1150.  ]
#  [2452.02 3499.  ]
#  [1565.97 1699.  ]
#  [ 920.49  980.  ]
#  [2025.9  2250.  ]
#  [1312.79 1106.  ]
#  [1200.84  780.  ]
#  [1103.11  945.  ]
#  [1103.11 1129.  ]
#  [1495.41 1319.  ]
#  [1450.98 1450.  ]
#  [1226.73  499.  ]
#  [ 977.52  859.  ]
#  [1184.28 1151.  ]
#  [ 893.44  725.  ]
#  [1701.24 1399.  ]
#  [ 852.85  839.  ]
#  [2117.68 2400.  ]
#  [1226.73  830.  ]
#  [1069.29 1175.  ]
#  [1556.29 1638.  ]
#  [ 954.31 1379.  ]
#  [ 873.14 1511.  ]
#  [ 970.87  930.  ]
#  [1454.83 1350.  ]
#  [1116.64  899.  ]
#  [1106.15 2559.  ]
#  [1525.38 1575.  ]
#  [ 791.98  850.  ]
#  [1224.86 1299.  ]
#  [1258.68  916.  ]
#  [1001.66 1099.  ]
#  [1308.94  895.  ]
#  [1572.73 1459.  ]
#  [3601.86 3199.  ]
#  [1326.32 1065.  ]
#  [ 879.91  915.  ]
#  [ 967.84  730.  ]
#  [1529.23 1320.  ]
#  [1103.11 1129.  ]
#  [ 697.29  500.  ]
#  [1802.82 1245.  ]
#  [ 866.38  760.  ]
#  [ 762.22  295.  ]
#  [1106.03  999.  ]
#  [1226.73 1150.  ]
#  [1139.85  895.  ]
#  [2090.62 3250.  ]
#  [1725.38 2345.  ]
#  [1211.33  920.  ]
#  [1197.81 1090.  ]
#  [1042.24 1000.  ]
#  [1292.5  1040.  ]
#  [1867.42 1246.  ]
#  [1226.73 1300.  ]
#  [1407.48 1350.  ]
#  [1400.72 1470.  ]
#  [1360.14 1075.  ]
#  [1197.81  995.  ]
#  [1103.11 1129.  ]
#  [1265.44 1680.  ]
#  [ 832.56 1948.  ]
#  [1146.61  848.  ]
#  [1103.11 1099.  ]
#  [1360.14 2483.  ]
#  [1021.95  855.  ]
#  [1226.73  648.  ]
#  [ 927.25  800.  ]
#  [1008.42 1390.  ]
#  [1278.16  769.  ]
#  [ 940.78  893.  ]
#  [1333.08 1149.  ]
#  [1226.73  959.  ]
#  [3240.46 3050.  ]
#  [ 889.71 1340.  ]
#  [1103.11 1099.  ]
#  [ 940.78  970.  ]
#  [2452.02 2844.  ]
#  [1234.54  939.  ]
#  [ 886.67 2032.  ]
#  [1088.78  992.  ]
#  [1258.68 1040.  ]
#  [1133.2  2414.  ]
#  [1035.47 2132.  ]
#  [1021.95 1159.  ]
#  [1136.93  955.  ]
#  [1254.83 1029.  ]
#  [1187.31 1200.  ]
#  [ 906.96  925.  ]
#  [ 954.31 1550.  ]
#  [ 886.67 1766.  ]
#  [1275.12  980.  ]
#  [1001.66  785.  ]
#  [1191.04 1190.  ]
#  [1123.4  1235.  ]
#  [1049.   1140.  ]
#  [ 852.85  839.  ]
#  [1146.61  850.  ]
#  [1089.59 2000.  ]
#  [ 977.52  859.  ]
#  [1062.53 1055.  ]
#  [1366.9   960.  ]
#  [1062.53 1090.  ]
#  [ 988.13 3520.  ]
#  [1369.94  964.  ]
#  [1478.04 1347.  ]
#  [1136.93  950.  ]
#  [1133.2  1390.  ]
#  [1339.84  499.  ]
#  [ 940.78  525.  ]
#  [1222.88 1713.  ]
#  [1264.09  933.  ]
#  [ 852.85  815.  ]
#  [ 984.4   900.  ]
#  [1251.92 1306.  ]
#  [1265.44 1269.  ]
#  [1092.16 1190.  ]]

# %% [markdown]
# ## Predicting a new result with Linear Regression

# %%
# The number of rooms has wrong out come so its better to remove it
print(lin_reg.predict([[40, 1, 1]]))
# Out:
# [1102.3]
